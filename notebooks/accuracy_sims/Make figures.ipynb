# %%
import scipy
import scipy.fftpack
import scipy.special
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import time
from pathlib import Path
import pickle
import timeit
import sys, os
import pandas as pd

# %%
# !ls output
# Out:
# KE_surface_open    KE_surface_open_test  OD_rod_closed_2  UD_rod_closed_2
# KE_surface_open_3  OD_rod_closed	 UD_rod_closed	  UD_rod_closed_3

# %%
# !ls output/KE_surface_open_3/
# Out:
# random_velocity_rand_1708K	    random_velocity_rand_EU0PJ
# random_velocity_rand_1708K_results  random_velocity_rand_EU0PJ_results
# random_velocity_rand_3HB04	    random_velocity_rand_GBQLQ
# random_velocity_rand_3HB04_results  random_velocity_rand_GBQLQ_results
# random_velocity_rand_4A0BR	    random_velocity_rand_HZABB
# random_velocity_rand_4A0BR_results  random_velocity_rand_HZABB_results
# random_velocity_rand_4PDL9	    random_velocity_rand_K56XG
# random_velocity_rand_4PDL9_results  random_velocity_rand_K56XG_results
# random_velocity_rand_57CQG	    random_velocity_rand_KVMNH
# random_velocity_rand_57CQG_results  random_velocity_rand_KVMNH_results
# random_velocity_rand_6UPQY	    random_velocity_rand_LF58A
# random_velocity_rand_6UPQY_results  random_velocity_rand_LF58A_results
# random_velocity_rand_76B98	    random_velocity_rand_UMOTQ
# random_velocity_rand_76B98_results  random_velocity_rand_UMOTQ_results
# random_velocity_rand_7FI68	    random_velocity_rand_UXJJT
# ...

# %%
# !ls output/UD_rod_closed_3/
# Out:
# random_force_rand_19NFX		 random_force_rand_O9FXR
# random_force_rand_247AO		 random_force_rand_OLOOO
# random_force_rand_686KH		 random_force_rand_QRXGA
# random_force_rand_8YSUJ		 random_force_rand_R2WMW
# random_force_rand_92X0G		 random_force_rand_T2IOE
# random_force_rand_9695O		 random_force_rand_V0YIG
# random_force_rand_9695O_results  random_force_rand_X3FE9
# random_force_rand_9EJGD		 random_force_rand_YD03F
# random_force_rand_CY7H2		 random_force_rand_YD03F_results
# random_force_rand_DD4SZ		 random_force_rand_YLO2R
# random_force_rand_ELKK0		 random_force_rand_YX8TT
# random_force_rand_FU284		 random_force_rand_ZU1MY
# random_force_rand_IKT1Q		 random_force_rand_ZU1MY_results
# random_force_rand_M6DMQ

# %%
# !ls output/UD_rod_closed/
# Out:
# random_force1			 random_force_rand_FHER5
# random_force1_results		 random_force_rand_FHER5_results
# random_force2			 random_force_rand_FVODO
# random_force2_results		 random_force_rand_FVODO_results
# random_force_rand_03FJ8		 random_force_rand_GB3YN
# random_force_rand_03FJ8_results  random_force_rand_GB3YN_results
# random_force_rand_0EGP1		 random_force_rand_GIXSI
# random_force_rand_0EGP1_results  random_force_rand_GIXSI_results
# random_force_rand_0MR76		 random_force_rand_GRK31
# random_force_rand_0MR76_results  random_force_rand_GRK31_results
# random_force_rand_0XOHW		 random_force_rand_H7HO2
# random_force_rand_0XOHW_results  random_force_rand_H7HO2_results
# random_force_rand_0YRJE		 random_force_rand_H8AC9
# random_force_rand_0YRJE_results  random_force_rand_H8AC9_results
# random_force_rand_21B1Z		 random_force_rand_HAZT5
# random_force_rand_21B1Z_results  random_force_rand_HAZT5_results
# random_force_rand_289JX		 random_force_rand_I79Q7
# ...

# %%
df = pd.read_csv(Path('output/UD_rod_closed/random_force1_results/close_error__v__dt.csv'))

xs = df['FE_dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
xs
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     0.000125
# 9     0.000100
# 10    0.000050
# 11    0.000025
# 12    0.000020
# 13    0.000013
# 14    0.000010
# 15    0.000005
# 16    0.000003
# 17    0.000002
# 18    0.000001
# 19    0.000001
# Name: FE_dt, dtype: float64

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/close_error__v__dt.csv'))

xs = df['FE_dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/UD_rod_closed/random_force1_results/Rf_sup_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/UD_rod_closed_3/random_force_rand_ZU1MY_results/close_error__v__dt.csv'))

xs = df['FE_dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/KE_surface_open_3/random_velocity_rand_1708K_results/integrability_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
close_error__v__dt

# %%
df = pd.read_csv(Path('output/OD_rod_closed_2/random_force_rand_HTUR3_results/Rf_sup_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
# !ls output/OD_rod_closed/

# %%
# !ls output/OD_rod_closed/random_force1_results
# Out:
# close_error__v__dt.csv		     Rf_sup_errs__v__dt.csv
# close_error__v__integrator_time.csv  Rf_sup_errs__v__integrator_time.csv
# Ef_sup_errs__v__dt.csv		     Rf_sup_errs__v__sim_run_time2.csv
# errors.txt			     Rf_sup_errs__v__sim_run_time.csv
# figs

# %%
# !ls output/KE_surface_open/random_velocity1_results
# Out:
# all_closed_errs.pkl	figs
# all_Ef_sup_err.pkl	integrability_errs__v__dt.csv
# all_integ_err.pkl	integrability_errs__v__sim_run_time2.csv
# all_Phif_sup_err.pkl	integrability_errs__v__sim_run_time.csv
# all_Rf_sup_err.pkl	Rf_sup_errs__v__dt.csv
# all_saved_dts.pkl	Rf_sup_errs__v__integrator_time.csv
# Ef_sup_errs__v__dt.csv	Rf_sup_errs__v__sim_run_time2.csv
# errors.txt		Rf_sup_errs__v__sim_run_time.csv

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/Rf_sup_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/KE_surface_open/random_velocity1_results/integrability_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/KE_surface_open/random_velocity2_results/integrability_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'], color='red')
plt.plot(xs, df['SO3'], color='blue')
plt.plot(xs, df['SE3'], color='green')

df = pd.read_csv(Path('output/KE_surface_open/random_velocity1_results/integrability_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'], color='red')
plt.plot(xs, df['SO3'], color='blue')
plt.plot(xs, df['SE3'], color='green')

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/KE_surface_open/random_velocity1_results/Ef_sup_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/KE_surface_open/random_velocity1_results/Ef_sup_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/close_error__v__dt.csv'))

xs = df['FE_dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force2_results/close_error__v__dt.csv'))

xs = df['FE_dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/close_error__v__dt.csv'))

xs = df['FE_dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/close_error__v__integrator_time.csv'))

plt.plot(df['FE_integrator_time'], df['FE'])
plt.plot(df['SO3_integrator_time'], df['SO3'])
plt.plot(df['SE3_integrator_time'], df['SE3'])

plt.yscale('log')

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/Rf_sup_errs__v__sim_run_time2.csv'))

xs = df['FE_sim_run_time2']

plt.plot(df['FE_sim_run_time2'], df['FE'])
plt.plot(df['SO3_sim_run_time2'], df['SO3'])
plt.plot(df['SE3_sim_run_time2'], df['SE3'])

plt.yscale('log')

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/Rf_sup_errs__v__dt.csv'))

xs = df['dt']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')

# %%
df = pd.read_csv(Path('output/OD_rod_closed/random_force1_results/Rf_sup_errs__v__integrator_time.csv'))

xs = df['FE_integrator_time']

plt.plot(xs, df['FE'])
plt.plot(xs, df['SO3'])
plt.plot(xs, df['SE3'])

plt.xscale('log')
plt.yscale('log')
